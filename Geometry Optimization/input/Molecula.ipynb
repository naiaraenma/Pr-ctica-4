# %% [markdown]
# ## GEOMETRY OPIMITZATION

# %% [markdown]
# passar molecula de Taxol de .xyz a fdf

# %% [markdown]
# Importem llibreria

# %%
from sisl import *

# %%
molecule=Geometry.read("Taxol.xyz")

# %%
molecule.plot()

# %%
molecule.write("structure.fdf")

# %%
structure=Geometry.read("structure.fdf")
structure.plot()
